# %% [markdown]
# # Deep Crossentropy method
#
# In this section we'll extend your CEM implementation with neural networks! You will train a multi-layer neural network to solve simple continuous state space games. __Please make sure you're done with tabular crossentropy method from the previous notebook.__
#
# ![img](https://watanimg.elwatannews.com/old_news_images/large/249765_Large_20140709045740_11.jpg)

# %%
import sys, os
if 'google.colab' in sys.modules and not os.path.exists('.setup_complete'):
    # !wget -q https://raw.githubusercontent.com/yandexdataschool/Practical_RL/master/setup_colab.sh -O- | bash
    # !touch .setup_complete

# This code creates a virtual display to draw game images on.
# It will have no effect if your machine has a monitor.
if type(os.environ.get("DISPLAY")) is not str or len(os.environ.get("DISPLAY")) == 0:
    # !bash ../xvfb start
    os.environ['DISPLAY'] = ':1'
# Out:
# ???????????? ????????? ???????? ??? ?????????? ????????.

# %%
# Install gymnasium if you didn't
# !pip install gymnasium[toy_text,classic_control,other]
# Out:
# Requirement already satisfied: gymnasium[classic_control,other,toy_text] in c:\python311\lib\site-packages (1.1.0)
# Requirement already satisfied: numpy>=1.21.0 in c:\python311\lib\site-packages (from gymnasium[classic_control,other,toy_text]) (2.2.3)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\python311\lib\site-packages (from gymnasium[classic_control,other,toy_text]) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\python311\lib\site-packages (from gymnasium[classic_control,other,toy_text]) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\python311\lib\site-packages (from gymnasium[classic_control,other,toy_text]) (0.0.4)
# Requirement already satisfied: pygame>=2.1.3 in c:\python311\lib\site-packages (from gymnasium[classic_control,other,toy_text]) (2.6.1)
# Collecting moviepy>=1.0.0 (from gymnasium[classic_control,other,toy_text])
#   Downloading moviepy-2.1.2-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: matplotlib>=3.0 in c:\python311\lib\site-packages (from gymnasium[classic_control,other,toy_text]) (3.10.1)
# Collecting opencv-python>=3.0 (from gymnasium[classic_control,other,toy_text])
#   Downloading opencv_python-4.11.0.86-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Collecting seaborn>=0.13 (from gymnasium[classic_control,other,toy_text])
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: contourpy>=1.0.1 in c:\python311\lib\site-packages (from matplotlib>=3.0->gymnasium[classic_control,other,toy_text]) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\python311\lib\site-packages (from matplotlib>=3.0->gymnasium[classic_control,other,toy_text]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\python311\lib\site-packages (from matplotlib>=3.0->gymnasium[classic_control,other,toy_text]) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\python311\lib\site-packages (from matplotlib>=3.0->gymnasium[classic_control,other,toy_text]) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\python311\lib\site-packages (from matplotlib>=3.0->gymnasium[classic_control,other,toy_text]) (24.2)
# Requirement already satisfied: pillow>=8 in c:\python311\lib\site-packages (from matplotlib>=3.0->gymnasium[classic_control,other,toy_text]) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\python311\lib\site-packages (from matplotlib>=3.0->gymnasium[classic_control,other,toy_text]) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\python311\lib\site-packages (from matplotlib>=3.0->gymnasium[classic_control,other,toy_text]) (2.9.0.post0)
# Requirement already satisfied: decorator<6.0,>=4.0.2 in c:\python311\lib\site-packages (from moviepy>=1.0.0->gymnasium[classic_control,other,toy_text]) (5.2.1)
# Collecting imageio<3.0,>=2.5 (from moviepy>=1.0.0->gymnasium[classic_control,other,toy_text])
#   Downloading imageio-2.37.0-py3-none-any.whl.metadata (5.2 kB)
# Collecting imageio_ffmpeg>=0.2.0 (from moviepy>=1.0.0->gymnasium[classic_control,other,toy_text])
#   Downloading imageio_ffmpeg-0.6.0-py3-none-win_amd64.whl.metadata (1.5 kB)
# Collecting proglog<=1.0.0 (from moviepy>=1.0.0->gymnasium[classic_control,other,toy_text])
#   Downloading proglog-0.1.10-py3-none-any.whl.metadata (639 bytes)
# Collecting python-dotenv>=0.10 (from moviepy>=1.0.0->gymnasium[classic_control,other,toy_text])
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Collecting pillow>=8 (from matplotlib>=3.0->gymnasium[classic_control,other,toy_text])
#   Downloading pillow-10.4.0-cp311-cp311-win_amd64.whl.metadata (9.3 kB)
# Requirement already satisfied: pandas>=1.2 in c:\python311\lib\site-packages (from seaborn>=0.13->gymnasium[classic_control,other,toy_text]) (2.2.3)
# Requirement already satisfied: pytz>=2020.1 in c:\python311\lib\site-packages (from pandas>=1.2->seaborn>=0.13->gymnasium[classic_control,other,toy_text]) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\python311\lib\site-packages (from pandas>=1.2->seaborn>=0.13->gymnasium[classic_control,other,toy_text]) (2025.1)
# Collecting tqdm (from proglog<=1.0.0->moviepy>=1.0.0->gymnasium[classic_control,other,toy_text])
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: six>=1.5 in c:\python311\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.0->gymnasium[classic_control,other,toy_text]) (1.17.0)
# Requirement already satisfied: colorama in c:\python311\lib\site-packages (from tqdm->proglog<=1.0.0->moviepy>=1.0.0->gymnasium[classic_control,other,toy_text]) (0.4.6)
# Downloading moviepy-2.1.2-py3-none-any.whl (126 kB)
# Downloading opencv_python-4.11.0.86-cp37-abi3-win_amd64.whl (39.5 MB)
#    ---------------------------------------- 0.0/39.5 MB ? eta -:--:--
#     --------------------------------------- 0.5/39.5 MB 2.8 MB/s eta 0:00:14
#    - -------------------------------------- 1.0/39.5 MB 2.6 MB/s eta 0:00:15
#    - -------------------------------------- 1.6/39.5 MB 2.6 MB/s eta 0:00:15
#    -- ------------------------------------- 2.1/39.5 MB 2.7 MB/s eta 0:00:15
#    -- ------------------------------------- 2.6/39.5 MB 2.6 MB/s eta 0:00:15
#    -- ------------------------------------- 2.9/39.5 MB 2.6 MB/s eta 0:00:15
#    --- ------------------------------------ 3.4/39.5 MB 2.5 MB/s eta 0:00:15
#    --- ------------------------------------ 3.9/39.5 MB 2.5 MB/s eta 0:00:15
#    ---- ----------------------------------- 4.5/39.5 MB 2.4 MB/s eta 0:00:15
#    ----- ---------------------------------- 5.0/39.5 MB 2.4 MB/s eta 0:00:15
#    ----- ---------------------------------- 5.5/39.5 MB 2.4 MB/s eta 0:00:14
#    ----- ---------------------------------- 5.8/39.5 MB 2.4 MB/s eta 0:00:14
#    ------ --------------------------------- 6.3/39.5 MB 2.4 MB/s eta 0:00:14
#    ------ --------------------------------- 6.8/39.5 MB 2.4 MB/s eta 0:00:14
#    ------- -------------------------------- 7.3/39.5 MB 2.4 MB/s eta 0:00:14
#    ------- -------------------------------- 7.6/39.5 MB 2.4 MB/s eta 0:00:14
#    -------- ------------------------------- 8.1/39.5 MB 2.4 MB/s eta 0:00:14
#    -------- ------------------------------- 8.7/39.5 MB 2.4 MB/s eta 0:00:13
#    --------- ------------------------------ 9.2/39.5 MB 2.4 MB/s eta 0:00:13
#    --------- ------------------------------ 9.7/39.5 MB 2.4 MB/s eta 0:00:13
#    ---------- ----------------------------- 10.0/39.5 MB 2.4 MB/s eta 0:00:13
#    ---------- ----------------------------- 10.5/39.5 MB 2.4 MB/s eta 0:00:13
#    ----------- ---------------------------- 11.0/39.5 MB 2.4 MB/s eta 0:00:13
#    ----------- ---------------------------- 11.5/39.5 MB 2.4 MB/s eta 0:00:12
#    ------------ --------------------------- 12.1/39.5 MB 2.4 MB/s eta 0:00:12
#    ------------ --------------------------- 12.6/39.5 MB 2.4 MB/s eta 0:00:12
#    ------------- -------------------------- 13.1/39.5 MB 2.4 MB/s eta 0:00:12
#    ------------- -------------------------- 13.4/39.5 MB 2.4 MB/s eta 0:00:12
#    -------------- ------------------------- 13.9/39.5 MB 2.4 MB/s eta 0:00:11
#    -------------- ------------------------- 14.4/39.5 MB 2.4 MB/s eta 0:00:11
#    --------------- ------------------------ 14.9/39.5 MB 2.4 MB/s eta 0:00:11
#    --------------- ------------------------ 15.5/39.5 MB 2.4 MB/s eta 0:00:11
#    ---------------- ----------------------- 16.0/39.5 MB 2.4 MB/s eta 0:00:10
#    ---------------- ----------------------- 16.3/39.5 MB 2.4 MB/s eta 0:00:10
#    ---------------- ----------------------- 16.8/39.5 MB 2.4 MB/s eta 0:00:10
#    ----------------- ---------------------- 17.3/39.5 MB 2.4 MB/s eta 0:00:10
#    ------------------ --------------------- 17.8/39.5 MB 2.4 MB/s eta 0:00:10
#    ------------------ --------------------- 18.4/39.5 MB 2.4 MB/s eta 0:00:09
#    ------------------- -------------------- 18.9/39.5 MB 2.4 MB/s eta 0:00:09
#    ------------------- -------------------- 19.4/39.5 MB 2.4 MB/s eta 0:00:09
#    ------------------- -------------------- 19.7/39.5 MB 2.4 MB/s eta 0:00:09
#    -------------------- ------------------- 20.2/39.5 MB 2.4 MB/s eta 0:00:09
#    -------------------- ------------------- 20.7/39.5 MB 2.4 MB/s eta 0:00:08
#    --------------------- ------------------ 21.2/39.5 MB 2.4 MB/s eta 0:00:08
#    ---------------------- ----------------- 21.8/39.5 MB 2.4 MB/s eta 0:00:08
#    ---------------------- ----------------- 22.3/39.5 MB 2.4 MB/s eta 0:00:08
#    ----------------------- ---------------- 22.8/39.5 MB 2.4 MB/s eta 0:00:08
#    ----------------------- ---------------- 23.3/39.5 MB 2.4 MB/s eta 0:00:07
#    ------------------------ --------------- 23.9/39.5 MB 2.4 MB/s eta 0:00:07
#    ------------------------ --------------- 24.4/39.5 MB 2.4 MB/s eta 0:00:07
#    ------------------------- -------------- 24.9/39.5 MB 2.4 MB/s eta 0:00:07
#    ------------------------- -------------- 25.4/39.5 MB 2.4 MB/s eta 0:00:06
#    -------------------------- ------------- 26.0/39.5 MB 2.4 MB/s eta 0:00:06
#    -------------------------- ------------- 26.5/39.5 MB 2.4 MB/s eta 0:00:06
#    --------------------------- ------------ 27.0/39.5 MB 2.4 MB/s eta 0:00:06
#    --------------------------- ------------ 27.3/39.5 MB 2.4 MB/s eta 0:00:06
#    ---------------------------- ----------- 28.0/39.5 MB 2.4 MB/s eta 0:00:05
#    ---------------------------- ----------- 28.3/39.5 MB 2.4 MB/s eta 0:00:05
#    ----------------------------- ---------- 28.8/39.5 MB 2.4 MB/s eta 0:00:05
#    ----------------------------- ---------- 29.4/39.5 MB 2.4 MB/s eta 0:00:05
#    ------------------------------ --------- 29.9/39.5 MB 2.4 MB/s eta 0:00:05
#    ------------------------------ --------- 30.4/39.5 MB 2.4 MB/s eta 0:00:04
#    ------------------------------- -------- 30.9/39.5 MB 2.4 MB/s eta 0:00:04
#    ------------------------------- -------- 31.5/39.5 MB 2.4 MB/s eta 0:00:04
#    -------------------------------- ------- 32.0/39.5 MB 2.4 MB/s eta 0:00:04
#    -------------------------------- ------- 32.5/39.5 MB 2.4 MB/s eta 0:00:03
#    --------------------------------- ------ 33.0/39.5 MB 2.4 MB/s eta 0:00:03
#    --------------------------------- ------ 33.6/39.5 MB 2.4 MB/s eta 0:00:03
#    ---------------------------------- ----- 34.1/39.5 MB 2.4 MB/s eta 0:00:03
#    ----------------------------------- ---- 34.6/39.5 MB 2.4 MB/s eta 0:00:03
#    ----------------------------------- ---- 34.9/39.5 MB 2.4 MB/s eta 0:00:02
#    ----------------------------------- ---- 35.4/39.5 MB 2.4 MB/s eta 0:00:02
#    ------------------------------------ --- 35.9/39.5 MB 2.4 MB/s eta 0:00:02
#    ------------------------------------ --- 36.4/39.5 MB 2.4 MB/s eta 0:00:02
#    ------------------------------------- -- 37.0/39.5 MB 2.4 MB/s eta 0:00:02
#    ------------------------------------- -- 37.5/39.5 MB 2.4 MB/s eta 0:00:01
#    -------------------------------------- - 38.0/39.5 MB 2.4 MB/s eta 0:00:01
#    ---------------------------------------  38.5/39.5 MB 2.4 MB/s eta 0:00:01
#    ---------------------------------------  39.1/39.5 MB 2.4 MB/s eta 0:00:01
#    ---------------------------------------  39.3/39.5 MB 2.4 MB/s eta 0:00:01
#    ---------------------------------------- 39.5/39.5 MB 2.4 MB/s eta 0:00:00
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Downloading imageio-2.37.0-py3-none-any.whl (315 kB)
# Downloading imageio_ffmpeg-0.6.0-py3-none-win_amd64.whl (31.2 MB)
#    ---------------------------------------- 0.0/31.2 MB ? eta -:--:--
#     --------------------------------------- 0.5/31.2 MB 2.4 MB/s eta 0:00:13
#    - -------------------------------------- 0.8/31.2 MB 2.4 MB/s eta 0:00:13
#    - -------------------------------------- 1.3/31.2 MB 2.5 MB/s eta 0:00:13
#    -- ------------------------------------- 1.8/31.2 MB 2.4 MB/s eta 0:00:13
#    --- ------------------------------------ 2.4/31.2 MB 2.4 MB/s eta 0:00:12
#    --- ------------------------------------ 2.9/31.2 MB 2.4 MB/s eta 0:00:12
#    ---- ----------------------------------- 3.4/31.2 MB 2.4 MB/s eta 0:00:12
#    ----- ---------------------------------- 3.9/31.2 MB 2.4 MB/s eta 0:00:12
#    ----- ---------------------------------- 4.5/31.2 MB 2.4 MB/s eta 0:00:12
#    ------ --------------------------------- 4.7/31.2 MB 2.4 MB/s eta 0:00:11
#    ------ --------------------------------- 5.2/31.2 MB 2.4 MB/s eta 0:00:11
#    ------- -------------------------------- 5.8/31.2 MB 2.4 MB/s eta 0:00:11
#    -------- ------------------------------- 6.3/31.2 MB 2.4 MB/s eta 0:00:11
#    -------- ------------------------------- 6.8/31.2 MB 2.4 MB/s eta 0:00:11
#    --------- ------------------------------ 7.3/31.2 MB 2.4 MB/s eta 0:00:10
#    ---------- ----------------------------- 7.9/31.2 MB 2.4 MB/s eta 0:00:10
#    ---------- ----------------------------- 8.4/31.2 MB 2.4 MB/s eta 0:00:10
#    ----------- ---------------------------- 8.7/31.2 MB 2.4 MB/s eta 0:00:10
#    ----------- ---------------------------- 9.2/31.2 MB 2.4 MB/s eta 0:00:10
#    ------------ --------------------------- 9.7/31.2 MB 2.4 MB/s eta 0:00:09
#    ------------- -------------------------- 10.2/31.2 MB 2.4 MB/s eta 0:00:09
#    ------------- -------------------------- 10.7/31.2 MB 2.4 MB/s eta 0:00:09
#    -------------- ------------------------- 11.3/31.2 MB 2.4 MB/s eta 0:00:09
#    --------------- ------------------------ 11.8/31.2 MB 2.4 MB/s eta 0:00:09
#    --------------- ------------------------ 12.3/31.2 MB 2.4 MB/s eta 0:00:08
#    ---------------- ----------------------- 12.6/31.2 MB 2.4 MB/s eta 0:00:08
#    ---------------- ----------------------- 13.1/31.2 MB 2.4 MB/s eta 0:00:08
#    ----------------- ---------------------- 13.6/31.2 MB 2.4 MB/s eta 0:00:08
#    ------------------ --------------------- 14.2/31.2 MB 2.4 MB/s eta 0:00:08
#    ------------------ --------------------- 14.7/31.2 MB 2.4 MB/s eta 0:00:07
#    ------------------- -------------------- 15.2/31.2 MB 2.4 MB/s eta 0:00:07
#    -------------------- ------------------- 15.7/31.2 MB 2.4 MB/s eta 0:00:07
#    -------------------- ------------------- 16.3/31.2 MB 2.4 MB/s eta 0:00:07
#    --------------------- ------------------ 16.8/31.2 MB 2.4 MB/s eta 0:00:06
#    ---------------------- ----------------- 17.3/31.2 MB 2.4 MB/s eta 0:00:06
#    ---------------------- ----------------- 17.8/31.2 MB 2.4 MB/s eta 0:00:06
#    ----------------------- ---------------- 18.1/31.2 MB 2.4 MB/s eta 0:00:06
#    ----------------------- ---------------- 18.6/31.2 MB 2.4 MB/s eta 0:00:06
#    ------------------------ --------------- 19.1/31.2 MB 2.4 MB/s eta 0:00:05
#    ------------------------- -------------- 19.7/31.2 MB 2.4 MB/s eta 0:00:05
#    ------------------------- -------------- 20.2/31.2 MB 2.4 MB/s eta 0:00:05
#    -------------------------- ------------- 20.7/31.2 MB 2.4 MB/s eta 0:00:05
#    --------------------------- ------------ 21.2/31.2 MB 2.4 MB/s eta 0:00:05
#    --------------------------- ------------ 21.8/31.2 MB 2.4 MB/s eta 0:00:04
#    ---------------------------- ----------- 22.3/31.2 MB 2.4 MB/s eta 0:00:04
#    ----------------------------- ---------- 22.8/31.2 MB 2.4 MB/s eta 0:00:04
#    ----------------------------- ---------- 23.3/31.2 MB 2.4 MB/s eta 0:00:04
#    ------------------------------ --------- 23.9/31.2 MB 2.4 MB/s eta 0:00:04
#    ------------------------------- -------- 24.4/31.2 MB 2.4 MB/s eta 0:00:03
#    ------------------------------- -------- 24.6/31.2 MB 2.4 MB/s eta 0:00:03
#    -------------------------------- ------- 25.2/31.2 MB 2.4 MB/s eta 0:00:03
#    -------------------------------- ------- 25.7/31.2 MB 2.4 MB/s eta 0:00:03
#    --------------------------------- ------ 26.2/31.2 MB 2.4 MB/s eta 0:00:03
#    ---------------------------------- ----- 26.7/31.2 MB 2.4 MB/s eta 0:00:02
#    ---------------------------------- ----- 27.3/31.2 MB 2.4 MB/s eta 0:00:02
#    ----------------------------------- ---- 27.8/31.2 MB 2.4 MB/s eta 0:00:02
#    ------------------------------------ --- 28.3/31.2 MB 2.4 MB/s eta 0:00:02
#    ------------------------------------ --- 28.8/31.2 MB 2.4 MB/s eta 0:00:01
#    ------------------------------------- -- 29.4/31.2 MB 2.4 MB/s eta 0:00:01
#    ------------------------------------- -- 29.6/31.2 MB 2.4 MB/s eta 0:00:01
#    -------------------------------------- - 30.1/31.2 MB 2.4 MB/s eta 0:00:01
#    ---------------------------------------  30.7/31.2 MB 2.4 MB/s eta 0:00:01
#    ---------------------------------------- 31.2/31.2 MB 2.4 MB/s eta 0:00:00
# Downloading pillow-10.4.0-cp311-cp311-win_amd64.whl (2.6 MB)
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.6 MB 2.4 MB/s eta 0:00:01
#    ------------ --------------------------- 0.8/2.6 MB 2.4 MB/s eta 0:00:01
#    -------------------- ------------------- 1.3/2.6 MB 2.5 MB/s eta 0:00:01
#    ---------------------------- ----------- 1.8/2.6 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------- 2.6/2.6 MB 2.5 MB/s eta 0:00:00
# Downloading proglog-0.1.10-py3-none-any.whl (6.1 kB)
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
# Installing collected packages: tqdm, python-dotenv, pillow, opencv-python, imageio_ffmpeg, proglog, imageio, seaborn, moviepy
#   Attempting uninstall: pillow
#     Found existing installation: pillow 11.1.0
#     Uninstalling pillow-11.1.0:
#       Successfully uninstalled pillow-11.1.0
# Successfully installed imageio-2.37.0 imageio_ffmpeg-0.6.0 moviepy-2.1.2 opencv-python-4.11.0.86 pillow-10.4.0 proglog-0.1.10 python-dotenv-1.0.1 seaborn-0.13.2 tqdm-4.67.1
# WARNING: Ignoring invalid distribution ~otebook (C:\Python311\Lib\site-packages)
# DEPRECATION: Loading egg at c:\python311\lib\site-packages\vboxapi-1.0-py3.11.egg is deprecated. pip 25.1 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# WARNING: Ignoring invalid distribution ~otebook (C:\Python311\Lib\site-packages)
#   WARNING: Failed to remove contents in a temporary directory 'C:\Python311\Lib\site-packages\~il'.
#   You can safely remove it manually.
# WARNING: Ignoring invalid distribution ~otebook (C:\Python311\Lib\site-packages)

# %%
import gymnasium as gym
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# if you see "<classname> has no attribute .env", remove .env or update gym
env = gym.make("CartPole-v0", render_mode="rgb_array").env

env.reset()
n_actions = env.action_space.n
state_dim = env.observation_space.shape[0]

plt.imshow(env.render())
print("state vector dim =", state_dim)
print("n_actions =", n_actions)

env.close()
# Out:
# C:\Python311\Lib\site-packages\gymnasium\envs\registration.py:519: DeprecationWarning: WARN: The environment CartPole-v0 is out of date. You should consider upgrading to version `v1`.
#   logger.deprecation(
# state vector dim = 4
# n_actions = 2

# %% [markdown]
# # Neural Network Policy
#
# For this assignment we'll utilize the simplified neural network implementation from __[Scikit-learn](https://scikit-learn.org/stable/modules/generated/sklearn.neural_network.MLPClassifier.html)__. Here's what you'll need:
#
# * `agent.partial_fit(states, actions)` - make a single training pass over the data. Maximize the probability of :actions: from :states:
# * `agent.predict_proba(states)` - predict probabilities of all actions, a matrix of shape __[len(states), n_actions]__

# %%
# !pip install sklearn
# !pip install scikit-learn

# %%
from sklearn.neural_network import MLPClassifier

agent = MLPClassifier(
    hidden_layer_sizes=(20, 20),
    activation="tanh",
)

# initialize agent to the dimension of state space and number of actions
agent.partial_fit([env.reset()[0]] * n_actions, range(n_actions), range(n_actions))
# Out:
# MLPClassifier(activation='tanh', hidden_layer_sizes=(20, 20))

# %%
def generate_session(env, agent, t_max=1000):
    """
    Play a single game using agent neural network.
    Terminate when game finishes or after :t_max: steps
    """
    states, actions = [], []
    total_reward = 0

    s, _ = env.reset()

    for t in range(t_max):

        # use agent to predict a vector of action probabilities for state :s:
        probs = agent.predict_proba([s])[0]

        assert probs.shape == (env.action_space.n,), "make sure probabilities are a vector (hint: np.reshape)"

        # use the probabilities you predicted to pick an action
        # sample proportionally to the probabilities, don't just take the most likely action
        a = np.random.choice(range(env.action_space.n), p=probs)
        # ^-- hint: try np.random.choice

        new_s, r, terminated, truncated, _ = env.step(a)

        # record sessions like you did before
        states.append(s)
        actions.append(a)
        total_reward += r

        s = new_s
        if terminated or truncated:
            break
    return states, actions, total_reward

# %%
dummy_states, dummy_actions, dummy_reward = generate_session(env, agent, t_max=5)
print("states:", np.stack(dummy_states))
print("actions:", dummy_actions)
print("reward:", dummy_reward)
# Out:
# states: [[ 0.00260486 -0.0039546   0.02945135  0.02142433]
#  [ 0.00252577 -0.19948626  0.02987983  0.32325208]
#  [-0.00146395 -0.00480224  0.03634487  0.04013976]
#  [-0.00156    -0.20042601  0.03714767  0.34406468]
#  [-0.00556852 -0.00585168  0.04402896  0.06332342]]
# actions: [np.int64(0), np.int64(1), np.int64(0), np.int64(1), np.int64(0)]
# reward: 5.0

# %% [markdown]
# ### CEM steps
# Deep CEM uses exactly the same strategy as the regular CEM, so you can copy your function code from previous notebook.
#
# The only difference is that now each observation is not a number but a `float32` vector.

# %%
def select_elites(states_batch, actions_batch, rewards_batch, percentile=50):
    """
    Select states and actions from games that have rewards >= percentile
    :param states_batch: list of lists of states, states_batch[session_i][t]
    :param actions_batch: list of lists of actions, actions_batch[session_i][t]
    :param rewards_batch: list of rewards, rewards_batch[session_i]

    :returns: elite_states,elite_actions, both 1D lists of states and respective actions from elite sessions

    Please return elite states and actions in their original order
    [i.e. sorted by session number and timestep within session]

    If you are confused, see examples below. Please don't assume that states are integers
    (they will become different later).
    """

    reward_threshold = np.percentile(rewards_batch, q=percentile)

    elite_states = []
    elite_actions = []
    for i in range(len(rewards_batch)):
        if rewards_batch[i] >= reward_threshold:
            elite_states.extend(states_batch[i])
            elite_actions.extend(actions_batch[i])

    return elite_states, elite_actions

# %% [markdown]
# # Training loop
# Generate sessions, select N best and fit to those.

# %%
from IPython.display import clear_output


def show_progress(rewards_batch, log, percentile, reward_range=[-990, +10]):
    """
    A convenience function that displays training progress.
    No cool math here, just charts.
    """

    mean_reward = np.mean(rewards_batch)
    threshold = np.percentile(rewards_batch, percentile)
    log.append([mean_reward, threshold])

    clear_output(True)
    print("mean reward = %.3f, threshold=%.3f" % (mean_reward, threshold))
    plt.figure(figsize=[8, 4])
    plt.subplot(1, 2, 1)
    plt.plot(list(zip(*log))[0], label="Mean rewards")
    plt.plot(list(zip(*log))[1], label="Reward thresholds")
    plt.legend()
    plt.grid()

    plt.subplot(1, 2, 2)
    plt.hist(rewards_batch, range=reward_range)
    plt.vlines(
        [np.percentile(rewards_batch, percentile)],
        [0],
        [100],
        label="percentile",
        color="red",
    )
    plt.legend()
    plt.grid()

    plt.show()

# %%
n_sessions = 100
percentile = 70
log = []

for i in range(100):
    # generate new sessions
    sessions = [generate_session(env, agent) for _ in range(n_sessions)]

    # states_batch, actions_batch, rewards_batch = map(np.array, zip(*sessions))

    states_batch = [session[0] for session in sessions]  # List of lists of states
    actions_batch = [session[1] for session in sessions]  # List of lists of actions
    rewards_batch = np.array([session[2] for session in sessions])  # Array of rewards

    elite_states, elite_actions = select_elites(states_batch, actions_batch, rewards_batch, percentile)

    agent.partial_fit(elite_states, elite_actions)

    show_progress(
        rewards_batch, log, percentile, reward_range=[0, np.max(rewards_batch)]
    )

    if np.mean(rewards_batch) > 190:
        print("You Win! You may stop training now via KeyboardInterrupt.")
# Out:
# mean reward = 984.500, threshold=1000.000
# You Win! You may stop training now via KeyboardInterrupt.

# %% [markdown]
# # Results

# %%
# Record sessions

from gymnasium.wrappers import RecordVideo

with RecordVideo(
    env=gym.make("CartPole-v0", render_mode="rgb_array"),
    video_folder="./videos",
    episode_trigger=lambda episode_number: True,
) as env_monitor:
    sessions = [generate_session(env_monitor, agent) for _ in range(100)]
# Out:
# C:\Python311\Lib\site-packages\gymnasium\wrappers\rendering.py:283: UserWarning: WARN: Overwriting existing videos at C:\RL\Practical_RL\week01_intro\videos folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(

# %%
# Show video. This may not work in some setups. If it doesn't
# work for you, you can download the videos and view them locally.

from pathlib import Path
from base64 import b64encode
from IPython.display import HTML

video_paths = sorted([s for s in Path("videos").iterdir() if s.suffix == ".mp4"])
video_path = video_paths[-1]  # You can also try other indices

if "google.colab" in sys.modules:
    # https://stackoverflow.com/a/57378660/1214547
    with video_path.open("rb") as fp:
        mp4 = fp.read()
    data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
else:
    data_url = str(video_path)

HTML(
    """
<video width="640" height="480" controls>
  <source src="{}" type="video/mp4">
</video>
""".format(
        data_url
    )
)
# Out:
# <video width="640" height="480" controls>
#   <source src="videos\rl-video-episode-99.mp4" type="video/mp4">
# </video>

# %% [markdown]
# # Homework part I
#
# ### Tabular crossentropy method
#
# You may have noticed that the taxi problem quickly converges from -100 to a near-optimal score and then descends back into -50/-100. This is in part because the environment has some innate randomness. Namely, the starting points of passenger/driver change from episode to episode.
#
# ### Tasks
# - __1.1__ (2 pts) Find out how the algorithm performance changes if you use a different `percentile` and/or `n_sessions`. Provide here some figures so we can see how the hyperparameters influence the performance.
# - __1.2__ (1 pts) Tune the algorithm to end up with positive average score.
#
# It's okay to modify the existing code.

# %% [markdown]
# ```Установка percentile<40 и percentile>60 не имеет смысла при любом n_sessions, т.к. происходит уменьшение mean rewards. Так же n_sessions<200 или n_sessions>300 при percestile>=50 и percentile<=60 показывают mean rewards в среднем -175. При значениях по умолчанию n_sessions=250, percentile=50 mean rewards растёт в среднем до -125```

# %% [markdown]
# # Homework part II
#
# ### Deep crossentropy method
#
# By this moment, you should have got enough score on [CartPole-v0](https://gymnasium.farama.org/environments/classic_control/cart_pole/) to consider it solved (see the link). It's time to try something harder.
#
# * if you have any trouble with CartPole-v0 and feel stuck, feel free to ask us or your peers for help.
#
# ### Tasks
#
# * __2.1__ (3 pts) Pick one of environments: `MountainCar-v0` or `LunarLander-v2`.
#   * For MountainCar, get average reward of __at least -150__
#   * For LunarLander, get average reward of __at least +50__
#
# See the tips section below, it's kinda important.
# __Note:__ If your agent is below the target score, you'll still get some of the points depending on the result, so don't be afraid to submit it.
#
#
# * __2.2__ (up to 6 pts) Devise a way to speed up training against the default version
#   * Obvious improvement: use [`joblib`](https://joblib.readthedocs.io/en/latest/). However, note that you will probably need to spawn a new environment in each of the workers instead of passing it via pickling. (2 pts)
#   * Try re-using samples from 3-5 last iterations when computing threshold and training. (2 pts)
#   * Obtain __-100__ at `MountainCar-v0` or __+200__ at `LunarLander-v2` (2 pts). Feel free to experiment with hyperparameters, architectures, schedules etc.
#
# __Please list what you did in Anytask submission form__. This reduces probability that somebody misses something.
#
#
# ### Tips
# * Gymnasium pages: [MountainCar](https://gymnasium.farama.org/environments/classic_control/mountain_car/), [LunarLander](https://gymnasium.farama.org/environments/box2d/lunar_lander/)
# * Sessions for MountainCar may last for 10k+ ticks. Make sure ```t_max``` param is at least 10k.
#  * Also it may be a good idea to cut rewards via ">" and not ">=". If 90% of your sessions get reward of -10k and 10% are better, than if you use percentile 20% as threshold, R >= threshold __fails to cut off bad sessions__ while R > threshold works alright.
# * _issue with gym_: Some versions of gym limit game time by 200 ticks. This will prevent cem training in most cases. Make sure your agent is able to play for the specified __t_max__, and if it isn't, try `env = gym.make("MountainCar-v0").env` or otherwise get rid of TimeLimit wrapper.
# * If you use old _swig_ lib for LunarLander-v2, you may get an error. See this [issue](https://github.com/openai/gym/issues/100) for solution.
# * If it doesn't train, it's a good idea to plot reward distribution and record sessions: they may give you some clue. If they don't, call course staff :)
# * 20-neuron network is probably not enough, feel free to experiment.
#
# You may find the following snippet useful:

# %%
env = gym.make("MountainCar-v0", render_mode="rgb_array")

# %%
def visualize_mountain_car(env, agent):
    # Compute policy for all possible x and v (with discretization)
    xs = np.linspace(env.min_position, env.max_position, 100)
    vs = np.linspace(-env.max_speed, env.max_speed, 100)

    grid = np.dstack(np.meshgrid(xs, vs[::-1])).transpose(1, 0, 2)
    grid_flat = grid.reshape(len(xs) * len(vs), 2)
    probs = (
        agent.predict_proba(grid_flat).reshape(len(xs), len(vs), 3).transpose(1, 0, 2)
    )

    # # The above code is equivalent to the following:
    # probs = np.empty((len(vs), len(xs), 3))
    # for i, v in enumerate(vs[::-1]):
    #     for j, x in enumerate(xs):
    #         probs[i, j, :] = agent.predict_proba([[x, v]])[0]

    # Draw policy
    f, ax = plt.subplots(figsize=(7, 7))
    ax.imshow(
        probs,
        extent=(env.min_position, env.max_position, -env.max_speed, env.max_speed),
        aspect="auto",
    )
    ax.set_title("Learned policy: red=left, green=nothing, blue=right")
    ax.set_xlabel("position (x)")
    ax.set_ylabel("velocity (v)")

    # Sample a trajectory and draw it
    states, actions, _ = generate_session(env, agent)
    states = np.array(states)
    ax.plot(states[:, 0], states[:, 1], color="white")

    # Draw every 3rd action from the trajectory
    for (x, v), a in zip(states[::3], actions[::3]):
        if a == 0:
            plt.arrow(x, v, -0.1, 0, color="white", head_length=0.02)
        elif a == 2:
            plt.arrow(x, v, 0.1, 0, color="white", head_length=0.02)


with gym.make("MountainCar-v0", render_mode="rgb_arrary").env as env:
    visualize_mountain_car(env, agent)
# Out:
# C:\Python311\Lib\site-packages\gymnasium\envs\registration.py:736: UserWarning: WARN: The environment is being initialised with render_mode='rgb_arrary' that is not in the possible render_modes (['human', 'rgb_array']).
#   logger.warn(
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[57], line 43
#      39             plt.arrow(x, v, 0.1, 0, color="white", head_length=0.02)
#      42 with gym.make("MountainCar-v0", render_mode="rgb_arrary").env as env:
# ---> 43     visualize_mountain_car(env, agent)
#
# Cell In[57], line 3, in visualize_mountain_car(env, agent)
#       1 def visualize_mountain_car(env, agent):
#       2     # Compute policy for all possible x and v (with discretization)
# ----> 3     xs = np.linspace(env.min_position, env.max_position, 100)
#       4     vs = np.linspace(-env.max_speed, env.max_speed, 100)
#       6     grid = np.dstack(np.meshgrid(xs, vs[::-1])).transpose(1, 0, 2)
#
# AttributeError: 'OrderEnforcing' object has no attribute 'min_position'

# %%
def generate_session(env, agent, t_max=10000):
    states, actions = [], []
    total_reward = 0

    s, _ = env.reset()

    for t in range(t_max):
        probs = agent.predict_proba([s])[0]

        a = np.random.choice(range(env.action_space.n), p=probs)

        new_s, r, terminated, truncated, _ = env.step(a)

        # Record the session
        states.append(s)
        actions.append(a)
        total_reward += r

        s = new_s
        if terminated or truncated:
            break

    return states, actions, total_reward

# %%
def select_elites(states_batch, actions_batch, rewards_batch, percentile):
    reward_threshold = np.percentile(rewards_batch, percentile)
    elite_states = []
    elite_actions = []
    for i in range(len(rewards_batch)):
        if rewards_batch[i] > reward_threshold:
            elite_states.extend(states_batch[i])
            elite_actions.extend(actions_batch[i])
    return elite_states, elite_actions

# %%
hidden_layer_sizes = (64, 64)
agent = MLPClassifier(
    hidden_layer_sizes=hidden_layer_sizes,
    activation="tanh",
    max_iter=1,
    warm_start=True,
)

agent.partial_fit([env.observation_space.sample()] * env.action_space.n, range(env.action_space.n), range(env.action_space.n))
# Out:
# MLPClassifier(activation='tanh', hidden_layer_sizes=(64, 64), max_iter=1,
#               warm_start=True)

# %%
n_sessions = 200
percentile = 50 
t_max = 10000
n_iterations = 100

log = []

for i in range(n_iterations):
    sessions = [generate_session(env, agent, t_max) for _ in range(n_sessions)]

    states_batch = [session[0] for session in sessions]
    actions_batch = [session[1] for session in sessions]
    rewards_batch = np.array([session[2] for session in sessions])

    reward_threshold = np.max(rewards_batch) - 50  # на всякий, чтоб работало

    elite_states = []
    elite_actions = []
    for j in range(len(rewards_batch)):
        if rewards_batch[j] > reward_threshold:
            elite_states.extend(states_batch[j])
            elite_actions.extend(actions_batch[j])

    if len(elite_states) == 0:
        print(f"Iteration {i}: No elite states found. Using random exploration.")
        # исп рандом на следующую итерацию
        agent = MLPClassifier(
            hidden_layer_sizes=(64, 64),
            activation="tanh",
            max_iter=1,
            warm_start=True,
        )
        agent.partial_fit([env.observation_space.sample()] * env.action_space.n, range(env.action_space.n), range(env.action_space.n))
        continue

    elite_states = np.array(elite_states)
    elite_actions = np.array(elite_actions)

    print(f"Iteration {i}: Elite States Shape = {elite_states.shape}, Elite Actions Shape = {elite_actions.shape}")

    agent.partial_fit(elite_states, elite_actions)

    mean_reward = np.mean(rewards_batch)
    threshold = reward_threshold
    log.append([mean_reward, threshold])

    print(f"Iteration {i}: Mean Reward = {mean_reward}, Threshold = {threshold}")

    if mean_reward > -150:
        print("Solved! Stopping training.")
        break

visualize_mountain_car(env, agent)
plt.show()
# Out:
# Iteration 0: Elite States Shape = (2000000, 2), Elite Actions Shape = (2000000,)
# Iteration 0: Mean Reward = -10000.0, Threshold = -10050.0
# Iteration 1: Elite States Shape = (6910, 2), Elite Actions Shape = (6910,)
# Iteration 1: Mean Reward = -9984.55, Threshold = -6960.0
# Iteration 2: Elite States Shape = (2000000, 2), Elite Actions Shape = (2000000,)
# Iteration 2: Mean Reward = -10000.0, Threshold = -10050.0
# Iteration 3: Elite States Shape = (2000000, 2), Elite Actions Shape = (2000000,)
# Iteration 3: Mean Reward = -10000.0, Threshold = -10050.0
# Iteration 4: Elite States Shape = (2000000, 2), Elite Actions Shape = (2000000,)
# Iteration 4: Mean Reward = -10000.0, Threshold = -10050.0
# Iteration 5: Elite States Shape = (2000000, 2), Elite Actions Shape = (2000000,)
# Iteration 5: Mean Reward = -10000.0, Threshold = -10050.0
# Iteration 6: Elite States Shape = (2000000, 2), Elite Actions Shape = (2000000,)
# Iteration 6: Mean Reward = -10000.0, Threshold = -10050.0
# Iteration 7: Elite States Shape = (2000000, 2), Elite Actions Shape = (2000000,)
# Iteration 7: Mean Reward = -10000.0, Threshold = -10050.0
# Iteration 8: Elite States Shape = (2000000, 2), Elite Actions Shape = (2000000,)
# Iteration 8: Mean Reward = -10000.0, Threshold = -10050.0
# Iteration 9: Elite States Shape = (2000000, 2), Elite Actions Shape = (2000000,)
# Iteration 9: Mean Reward = -10000.0, Threshold = -10050.0
# Iteration 10: Elite States Shape = (2000000, 2), Elite Actions Shape = (2000000,)
# Iteration 10: Mean Reward = -10000.0, Threshold = -10050.0
# Iteration 11: Elite States Shape = (2000000, 2), Elite Actions Shape = (2000000,)
# Iteration 11: Mean Reward = -10000.0, Threshold = -10050.0
# Iteration 12: Elite States Shape = (2000000, 2), Elite Actions Shape = (2000000,)
# Iteration 12: Mean Reward = -10000.0, Threshold = -10050.0
# Iteration 13: Elite States Shape = (2000000, 2), Elite Actions Shape = (2000000,)
# Iteration 13: Mean Reward = -10000.0, Threshold = -10050.0
# Iteration 14: Elite States Shape = (2000000, 2), Elite Actions Shape = (2000000,)
# Iteration 14: Mean Reward = -10000.0, Threshold = -10050.0
# Iteration 15: Elite States Shape = (2000000, 2), Elite Actions Shape = (2000000,)
# Iteration 15: Mean Reward = -10000.0, Threshold = -10050.0
# Iteration 16: Elite States Shape = (2000000, 2), Elite Actions Shape = (2000000,)
# Iteration 16: Mean Reward = -10000.0, Threshold = -10050.0
# Iteration 17: Elite States Shape = (2000000, 2), Elite Actions Shape = (2000000,)
# Iteration 17: Mean Reward = -10000.0, Threshold = -10050.0
# Iteration 18: Elite States Shape = (2000000, 2), Elite Actions Shape = (2000000,)
# Iteration 18: Mean Reward = -10000.0, Threshold = -10050.0
# Iteration 19: Elite States Shape = (2000000, 2), Elite Actions Shape = (2000000,)
# Iteration 19: Mean Reward = -10000.0, Threshold = -10050.0
# Iteration 20: Elite States Shape = (2000000, 2), Elite Actions Shape = (2000000,)
# Iteration 20: Mean Reward = -10000.0, Threshold = -10050.0
# Iteration 21: Elite States Shape = (2000000, 2), Elite Actions Shape = (2000000,)
# Iteration 21: Mean Reward = -10000.0, Threshold = -10050.0
# Iteration 22: Elite States Shape = (2000000, 2), Elite Actions Shape = (2000000,)
# Iteration 22: Mean Reward = -10000.0, Threshold = -10050.0
# Iteration 23: Elite States Shape = (2000000, 2), Elite Actions Shape = (2000000,)
# Iteration 23: Mean Reward = -10000.0, Threshold = -10050.0
# Iteration 24: Elite States Shape = (2000000, 2), Elite Actions Shape = (2000000,)
# Iteration 24: Mean Reward = -10000.0, Threshold = -10050.0
# Iteration 25: Elite States Shape = (2000000, 2), Elite Actions Shape = (2000000,)
# Iteration 25: Mean Reward = -10000.0, Threshold = -10050.0
# Iteration 26: Elite States Shape = (2000000, 2), Elite Actions Shape = (2000000,)
# Iteration 26: Mean Reward = -10000.0, Threshold = -10050.0
# Iteration 27: Elite States Shape = (3358, 2), Elite Actions Shape = (3358,)
# Iteration 27: Mean Reward = -9966.79, Threshold = -3408.0
# Iteration 28: Elite States Shape = (2000000, 2), Elite Actions Shape = (2000000,)
# Iteration 28: Mean Reward = -10000.0, Threshold = -10050.0
# Iteration 29: Elite States Shape = (2000000, 2), Elite Actions Shape = (2000000,)
# Iteration 29: Mean Reward = -10000.0, Threshold = -10050.0
# Iteration 30: Elite States Shape = (2000000, 2), Elite Actions Shape = (2000000,)
# Iteration 30: Mean Reward = -10000.0, Threshold = -10050.0
# Iteration 31: Elite States Shape = (2000000, 2), Elite Actions Shape = (2000000,)
# Iteration 31: Mean Reward = -10000.0, Threshold = -10050.0
# Iteration 32: Elite States Shape = (2000000, 2), Elite Actions Shape = (2000000,)
# Iteration 32: Mean Reward = -10000.0, Threshold = -10050.0
# Iteration 33: Elite States Shape = (2000000, 2), Elite Actions Shape = (2000000,)
# Iteration 33: Mean Reward = -10000.0, Threshold = -10050.0
# Iteration 34: Elite States Shape = (2000000, 2), Elite Actions Shape = (2000000,)
# Iteration 34: Mean Reward = -10000.0, Threshold = -10050.0
# Iteration 35: Elite States Shape = (2000000, 2), Elite Actions Shape = (2000000,)
# Iteration 35: Mean Reward = -10000.0, Threshold = -10050.0
# Iteration 36: Elite States Shape = (2000000, 2), Elite Actions Shape = (2000000,)
# Iteration 36: Mean Reward = -10000.0, Threshold = -10050.0
# Iteration 37: Elite States Shape = (2000000, 2), Elite Actions Shape = (2000000,)
# Iteration 37: Mean Reward = -10000.0, Threshold = -10050.0
# Iteration 38: Elite States Shape = (2000000, 2), Elite Actions Shape = (2000000,)
# Iteration 38: Mean Reward = -10000.0, Threshold = -10050.0
# Iteration 39: Elite States Shape = (2000000, 2), Elite Actions Shape = (2000000,)
# Iteration 39: Mean Reward = -10000.0, Threshold = -10050.0
# Iteration 40: Elite States Shape = (2000000, 2), Elite Actions Shape = (2000000,)
# Iteration 40: Mean Reward = -10000.0, Threshold = -10050.0
# Iteration 41: Elite States Shape = (2000000, 2), Elite Actions Shape = (2000000,)
# Iteration 41: Mean Reward = -10000.0, Threshold = -10050.0
# Iteration 42: Elite States Shape = (2000000, 2), Elite Actions Shape = (2000000,)
# Iteration 42: Mean Reward = -10000.0, Threshold = -10050.0
# Iteration 43: Elite States Shape = (2000000, 2), Elite Actions Shape = (2000000,)
# Iteration 43: Mean Reward = -10000.0, Threshold = -10050.0
# Iteration 44: Elite States Shape = (2000000, 2), Elite Actions Shape = (2000000,)
# Iteration 44: Mean Reward = -10000.0, Threshold = -10050.0
# Iteration 45: Elite States Shape = (2000000, 2), Elite Actions Shape = (2000000,)
# Iteration 45: Mean Reward = -10000.0, Threshold = -10050.0
# Iteration 46: Elite States Shape = (2000000, 2), Elite Actions Shape = (2000000,)
# Iteration 46: Mean Reward = -10000.0, Threshold = -10050.0
# Iteration 47: Elite States Shape = (2000000, 2), Elite Actions Shape = (2000000,)
# Iteration 47: Mean Reward = -10000.0, Threshold = -10050.0
# Iteration 48: Elite States Shape = (2000000, 2), Elite Actions Shape = (2000000,)
# Iteration 48: Mean Reward = -10000.0, Threshold = -10050.0
# Iteration 49: Elite States Shape = (2000000, 2), Elite Actions Shape = (2000000,)
# Iteration 49: Mean Reward = -10000.0, Threshold = -10050.0
# Iteration 50: Elite States Shape = (2000000, 2), Elite Actions Shape = (2000000,)
# Iteration 50: Mean Reward = -10000.0, Threshold = -10050.0
# Iteration 51: Elite States Shape = (2000000, 2), Elite Actions Shape = (2000000,)
# Iteration 51: Mean Reward = -10000.0, Threshold = -10050.0
# Iteration 52: Elite States Shape = (2000000, 2), Elite Actions Shape = (2000000,)
# Iteration 52: Mean Reward = -10000.0, Threshold = -10050.0
# Iteration 53: Elite States Shape = (2000000, 2), Elite Actions Shape = (2000000,)
# Iteration 53: Mean Reward = -10000.0, Threshold = -10050.0
# Iteration 54: Elite States Shape = (2000000, 2), Elite Actions Shape = (2000000,)
# Iteration 54: Mean Reward = -10000.0, Threshold = -10050.0
# Iteration 55: Elite States Shape = (2000000, 2), Elite Actions Shape = (2000000,)
# Iteration 55: Mean Reward = -10000.0, Threshold = -10050.0
# Iteration 56: Elite States Shape = (2000000, 2), Elite Actions Shape = (2000000,)
# Iteration 56: Mean Reward = -10000.0, Threshold = -10050.0
# Iteration 57: Elite States Shape = (2000000, 2), Elite Actions Shape = (2000000,)
# Iteration 57: Mean Reward = -10000.0, Threshold = -10050.0
# Iteration 58: Elite States Shape = (2000000, 2), Elite Actions Shape = (2000000,)
# Iteration 58: Mean Reward = -10000.0, Threshold = -10050.0
# Iteration 59: Elite States Shape = (2000000, 2), Elite Actions Shape = (2000000,)
# Iteration 59: Mean Reward = -10000.0, Threshold = -10050.0
# Iteration 60: Elite States Shape = (2000000, 2), Elite Actions Shape = (2000000,)
# Iteration 60: Mean Reward = -10000.0, Threshold = -10050.0
# Iteration 61: Elite States Shape = (2000000, 2), Elite Actions Shape = (2000000,)
# Iteration 61: Mean Reward = -10000.0, Threshold = -10050.0
# Iteration 62: Elite States Shape = (2000000, 2), Elite Actions Shape = (2000000,)
# Iteration 62: Mean Reward = -10000.0, Threshold = -10050.0
# Iteration 63: Elite States Shape = (2000000, 2), Elite Actions Shape = (2000000,)
# Iteration 63: Mean Reward = -10000.0, Threshold = -10050.0
# Iteration 64: Elite States Shape = (2000000, 2), Elite Actions Shape = (2000000,)
# Iteration 64: Mean Reward = -10000.0, Threshold = -10050.0
# Iteration 65: Elite States Shape = (2000000, 2), Elite Actions Shape = (2000000,)
# Iteration 65: Mean Reward = -10000.0, Threshold = -10050.0
# Iteration 66: Elite States Shape = (2000000, 2), Elite Actions Shape = (2000000,)
# Iteration 66: Mean Reward = -10000.0, Threshold = -10050.0
# Iteration 67: Elite States Shape = (2000000, 2), Elite Actions Shape = (2000000,)
# Iteration 67: Mean Reward = -10000.0, Threshold = -10050.0
# Iteration 68: Elite States Shape = (2000000, 2), Elite Actions Shape = (2000000,)
# Iteration 68: Mean Reward = -10000.0, Threshold = -10050.0
# Iteration 69: Elite States Shape = (2000000, 2), Elite Actions Shape = (2000000,)
# Iteration 69: Mean Reward = -10000.0, Threshold = -10050.0
# Iteration 70: Elite States Shape = (2000000, 2), Elite Actions Shape = (2000000,)
# Iteration 70: Mean Reward = -10000.0, Threshold = -10050.0
# Iteration 71: Elite States Shape = (2000000, 2), Elite Actions Shape = (2000000,)
# Iteration 71: Mean Reward = -10000.0, Threshold = -10050.0
# Iteration 72: Elite States Shape = (2000000, 2), Elite Actions Shape = (2000000,)
# Iteration 72: Mean Reward = -10000.0, Threshold = -10050.0
# Iteration 73: Elite States Shape = (2000000, 2), Elite Actions Shape = (2000000,)
# Iteration 73: Mean Reward = -10000.0, Threshold = -10050.0
# Iteration 74: Elite States Shape = (2000000, 2), Elite Actions Shape = (2000000,)
# Iteration 74: Mean Reward = -10000.0, Threshold = -10050.0
# Iteration 75: Elite States Shape = (2000000, 2), Elite Actions Shape = (2000000,)
# Iteration 75: Mean Reward = -10000.0, Threshold = -10050.0
# Iteration 76: Elite States Shape = (2000000, 2), Elite Actions Shape = (2000000,)
# Iteration 76: Mean Reward = -10000.0, Threshold = -10050.0
# Iteration 77: Elite States Shape = (2000000, 2), Elite Actions Shape = (2000000,)
# Iteration 77: Mean Reward = -10000.0, Threshold = -10050.0
# Iteration 78: Elite States Shape = (2000000, 2), Elite Actions Shape = (2000000,)
# Iteration 78: Mean Reward = -10000.0, Threshold = -10050.0
# Iteration 79: Elite States Shape = (2000000, 2), Elite Actions Shape = (2000000,)
# Iteration 79: Mean Reward = -10000.0, Threshold = -10050.0
# Iteration 80: Elite States Shape = (2000000, 2), Elite Actions Shape = (2000000,)
# Iteration 80: Mean Reward = -10000.0, Threshold = -10050.0
# Iteration 81: Elite States Shape = (2000000, 2), Elite Actions Shape = (2000000,)
# Iteration 81: Mean Reward = -10000.0, Threshold = -10050.0
# Iteration 82: Elite States Shape = (2000000, 2), Elite Actions Shape = (2000000,)
# Iteration 82: Mean Reward = -10000.0, Threshold = -10050.0
# Iteration 83: Elite States Shape = (2000000, 2), Elite Actions Shape = (2000000,)
# Iteration 83: Mean Reward = -10000.0, Threshold = -10050.0
# Iteration 84: Elite States Shape = (2000000, 2), Elite Actions Shape = (2000000,)
# Iteration 84: Mean Reward = -10000.0, Threshold = -10050.0
# Iteration 85: Elite States Shape = (2000000, 2), Elite Actions Shape = (2000000,)
# Iteration 85: Mean Reward = -10000.0, Threshold = -10050.0
# Iteration 86: Elite States Shape = (2000000, 2), Elite Actions Shape = (2000000,)
# Iteration 86: Mean Reward = -10000.0, Threshold = -10050.0
# Iteration 87: Elite States Shape = (2000000, 2), Elite Actions Shape = (2000000,)
# Iteration 87: Mean Reward = -10000.0, Threshold = -10050.0
# Iteration 88: Elite States Shape = (2000000, 2), Elite Actions Shape = (2000000,)
# Iteration 88: Mean Reward = -10000.0, Threshold = -10050.0
# Iteration 89: Elite States Shape = (2000000, 2), Elite Actions Shape = (2000000,)
# Iteration 89: Mean Reward = -10000.0, Threshold = -10050.0
# Iteration 90: Elite States Shape = (2000000, 2), Elite Actions Shape = (2000000,)
# Iteration 90: Mean Reward = -10000.0, Threshold = -10050.0
# Iteration 91: Elite States Shape = (2000000, 2), Elite Actions Shape = (2000000,)
# Iteration 91: Mean Reward = -10000.0, Threshold = -10050.0
# Iteration 92: Elite States Shape = (2000000, 2), Elite Actions Shape = (2000000,)
# Iteration 92: Mean Reward = -10000.0, Threshold = -10050.0
# Iteration 93: Elite States Shape = (3322, 2), Elite Actions Shape = (3322,)
# Iteration 93: Mean Reward = -9966.61, Threshold = -3372.0
# Iteration 94: Elite States Shape = (2000000, 2), Elite Actions Shape = (2000000,)
# Iteration 94: Mean Reward = -10000.0, Threshold = -10050.0
# Iteration 95: Elite States Shape = (2000000, 2), Elite Actions Shape = (2000000,)
# Iteration 95: Mean Reward = -10000.0, Threshold = -10050.0
# Iteration 96: Elite States Shape = (2000000, 2), Elite Actions Shape = (2000000,)
# Iteration 96: Mean Reward = -10000.0, Threshold = -10050.0
# Iteration 97: Elite States Shape = (2000000, 2), Elite Actions Shape = (2000000,)
# Iteration 97: Mean Reward = -10000.0, Threshold = -10050.0
# Iteration 98: Elite States Shape = (2000000, 2), Elite Actions Shape = (2000000,)
# Iteration 98: Mean Reward = -10000.0, Threshold = -10050.0
# Iteration 99: Elite States Shape = (2000000, 2), Elite Actions Shape = (2000000,)
# Iteration 99: Mean Reward = -10000.0, Threshold = -10050.0
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[61], line 53
#      50         print("Solved! Stopping training.")
#      51         break
# ---> 53 visualize_mountain_car(env, agent)
#      54 plt.show()
#
# Cell In[57], line 3, in visualize_mountain_car(env, agent)
#       1 def visualize_mountain_car(env, agent):
#       2     # Compute policy for all possible x and v (with discretization)
# ----> 3     xs = np.linspace(env.min_position, env.max_position, 100)
#       4     vs = np.linspace(-env.max_speed, env.max_speed, 100)
#       6     grid = np.dstack(np.meshgrid(xs, vs[::-1])).transpose(1, 0, 2)
#
# AttributeError: 'OrderEnforcing' object has no attribute 'min_position'

# %% [markdown]
# ### Bonus tasks
#
# * __2.3 bonus__ (2 pts) Try to find a network architecture and training params that solve __both__ environments above (_Points depend on implementation. If you attempted this task, please mention it in Anytask submission._)
#
# * __2.4 bonus__ (4 pts) Solve continuous action space task with `MLPRegressor` or similar.
#   * Since your agent only predicts the "expected" action, you will have to add noise to ensure exploration.
#   * Choose one of [MountainCarContinuous-v0](https://gymnasium.farama.org/environments/classic_control/mountain_car_continuous/) (90+ pts to solve), [LunarLanderContinuous-v2](https://gymnasium.farama.org/environments/box2d/lunar_lander/) (`env = gym.make("LunarLander-v2", continuous=True)`)(200+ pts to solve)
#   * 4 points for solving. Slightly less for getting some results below solution threshold. Note that discrete and continuous environments may have slightly different rules, aside from action spaces.
